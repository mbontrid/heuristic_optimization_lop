# %% [markdown]
# # Statistical analysis of lop algorithms implementation

# %% [markdown]
# ## setup

# %%
# !uv sync
# Out:
# warning: `VIRTUAL_ENV=/var/home/quatras/.cache/uv/archive-v0/tHTIbe1GjTIs3M2bpY6Jl` does not match the project environment path `.venv` and will be ignored
# Resolved 15 packages in 2ms
# Audited 13 packages in 0.03ms

# %%
import ast
import itertools
import subprocess
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import ttest_rel, wilcoxon

# %%
PATH_TO_OUT = Path("data/output")
PATH_TO_IN = Path("data/input")

PATH_TO_BEST_KNOWN = PATH_TO_IN / "best_known.txt"
PATH_TO_INSTANCES = PATH_TO_IN / "instances"
PATH_TO_OUTPUT_IT_IMP = PATH_TO_OUT / "it_im_results.csv"
PATH_TO_OUTPUT_VND = PATH_TO_OUT / "lop_vnd_results.csv"

PATH_TO_FIGS = PATH_TO_OUT / "figs/"

PATH_BENCHMARK = Path("tools/benchmark_best_known.py")


#benchmark parameters
N_WORKERS = 0
N_RUNS = 1

# %% [markdown]
# Search and compute raw measurement results of lop benchmark if not founds

# %%
if not PATH_TO_OUTPUT_IT_IMP.exists() or not PATH_TO_OUTPUT_VND.exists():
    if not PATH_BENCHMARK.exists():
        raise FileNotFoundError(f"Benchmark script not found: {PATH_BENCHMARK}")

    cmd = [
        "uv",
        "run",
        str(PATH_BENCHMARK),
        "--instances-dir",
        str(PATH_TO_INSTANCES),
        "--best_known_file",
        str(PATH_TO_BEST_KNOWN),
        "--output_it_imp",
        str(PATH_TO_OUTPUT_IT_IMP),
        "--output_vnd",
        str(PATH_TO_OUTPUT_VND),
        "--k",
        str(N_RUNS),
        "-w",
        str(N_WORKERS),
    ]
    exit_code = subprocess.call(cmd)
    if exit_code != 0:
        raise RuntimeError("Benchmark data could not be generated.")

# %%
RESULT_COLUMNS = [
    "instance",
    "best_known_cost",
    "sol_start",
    "pivot",
    "neighborhoods",
    "cost",
    "time_s",
]


def parse_neighborhoods(value: str) -> tuple[str, ...]:
    parsed = ast.literal_eval(value)
    if not isinstance(parsed, (list, tuple)):
        raise ValueError(f"Invalid neighborhoods value: {value}")
    return tuple(str(item) for item in parsed)


def load_results(path: Path) -> pd.DataFrame:
    df = pd.read_csv(path, usecols=RESULT_COLUMNS).copy()
    df["neighborhood_list"] = df["neighborhoods"].map(parse_neighborhoods)
    df["gap_pct"] = (df["best_known_cost"] - df["cost"]) / df["best_known_cost"] * 100.0
    return df


df_raw = pd.concat(
    [load_results(PATH_TO_OUTPUT_IT_IMP), load_results(PATH_TO_OUTPUT_VND)],
    ignore_index=True,
)

df_it_imp = df_raw[df_raw["neighborhood_list"].str.len() == 1].copy()
df_vnd = df_raw[df_raw["neighborhood_list"].str.len() > 1].copy()

df_it_imp["neighborhood"] = df_it_imp["neighborhood_list"].str[0]
df_it_imp["algorithm"] = (
    df_it_imp["sol_start"] + " | " + df_it_imp["pivot"] + " | " + df_it_imp["neighborhood"]
)
df_vnd["algorithm"] = df_vnd["neighborhood_list"].map(lambda n: " -> ".join(n))

print(f"Iterative improvement results: {len(df_it_imp)} rows")
print(f"VND results: {len(df_vnd)} rows")
print(df_it_imp)
print(df_vnd)
# Out:
# Iterative improvement results: 936 rows
# VND results: 156 rows
#            instance  best_known_cost sol_start  pivot  neighborhoods     cost  \
# 0     N-be75eec_150          3482828    random  first  ['transpose']  2131491
# 1     N-be75eec_150          3482828   c_and_w  first  ['transpose']  2657375
# 2     N-be75eec_150          3482828    random  first   ['exchange']  3397099
# 3     N-be75eec_150          3482828   c_and_w  first   ['exchange']  3375115
# 4     N-be75eec_150          3482828    random  first     ['insert']  3324546
# ..              ...              ...       ...    ...            ...      ...
# 931  N-tiw56r72_250          7451579   c_and_w   best  ['transpose']  5967381
# 932  N-tiw56r72_250          7451579    random   best   ['exchange']  7176154
# 933  N-tiw56r72_250          7451579   c_and_w   best   ['exchange']  7169751
# 934  N-tiw56r72_250          7451579    random   best     ['insert']  7200330
# 935  N-tiw56r72_250          7451579   c_and_w   best     ['insert']  7218135
#
#        time_s neighborhood_list    gap_pct neighborhood  \
# 0    0.000083      (transpose,)  38.799992    transpose
# 1    0.000082      (transpose,)  23.700654    transpose
# 2    2.038630       (exchange,)   2.461477     exchange
# 3    1.776130       (exchange,)   3.092688     exchange
# 4    0.560115         (insert,)   4.544640       insert
# ..        ...               ...        ...          ...
# 931  0.001057      (transpose,)  19.917899    transpose
# 932  4.516590       (exchange,)   3.696196     exchange
# 933  3.684980       (exchange,)   3.782125     exchange
# 934  5.274690         (insert,)   3.371755       insert
# 935  5.083410         (insert,)   3.132813       insert
#
#                        algorithm
# 0     random | first | transpose
# 1    c_and_w | first | transpose
# 2      random | first | exchange
# 3     c_and_w | first | exchange
# 4        random | first | insert
# ..                           ...
# 931   c_and_w | best | transpose
# 932     random | best | exchange
# 933    c_and_w | best | exchange
# 934       random | best | insert
# 935      c_and_w | best | insert
#
# [936 rows x 11 columns]
#             instance  best_known_cost sol_start  pivot  \
# 936    N-be75eec_150          3482828   c_and_w  first
# 937    N-be75eec_150          3482828   c_and_w  first
# 938     N-be75np_150          7174325   c_and_w  first
# 939     N-be75np_150          7174325   c_and_w  first
# 940     N-be75oi_150          2246534   c_and_w  first
# ...              ...              ...       ...    ...
# 1087  N-tiw56r66_250          4948414   c_and_w  first
# 1088  N-tiw56r67_250          5289658   c_and_w  first
# 1089  N-tiw56r67_250          5289658   c_and_w  first
# 1090  N-tiw56r72_250          7451579   c_and_w  first
# 1091  N-tiw56r72_250          7451579   c_and_w  first
#
#                             neighborhoods     cost    time_s  \
# 936   ['transpose', 'exchange', 'insert']  3395599   2.00168
# 937   ['transpose', 'insert', 'exchange']  3385021   1.02781
# 938   ['transpose', 'exchange', 'insert']  7042848   1.92918
# 939   ['transpose', 'insert', 'exchange']  6881430   1.03618
# 940   ['transpose', 'exchange', 'insert']  2225151   1.83237
# ...                                   ...      ...       ...
# 1087  ['transpose', 'insert', 'exchange']  4779103   8.07330
# 1088  ['transpose', 'exchange', 'insert']  5161349  14.82540
# 1089  ['transpose', 'insert', 'exchange']  5123741   8.47301
# 1090  ['transpose', 'exchange', 'insert']  7312646  12.14680
# 1091  ['transpose', 'insert', 'exchange']  7196928   7.12519
#
#                   neighborhood_list   gap_pct                        algorithm
# 936   (transpose, exchange, insert)  2.504545  transpose -> exchange -> insert
# 937   (transpose, insert, exchange)  2.808264  transpose -> insert -> exchange
# 938   (transpose, exchange, insert)  1.832604  transpose -> exchange -> insert
# 939   (transpose, insert, exchange)  4.082544  transpose -> insert -> exchange
# 940   (transpose, exchange, insert)  0.951822  transpose -> exchange -> insert
# ...                             ...       ...                              ...
# 1087  (transpose, insert, exchange)  3.421521  transpose -> insert -> exchange
# 1088  (transpose, exchange, insert)  2.425658  transpose -> exchange -> insert
# 1089  (transpose, insert, exchange)  3.136630  transpose -> insert -> exchange
# 1090  (transpose, exchange, insert)  1.864477  transpose -> exchange -> insert
# 1091  (transpose, insert, exchange)  3.417410  transpose -> insert -> exchange
#
# [156 rows x 10 columns]

# %%
it_summary = (
    df_it_imp.groupby(["sol_start", "pivot", "neighborhood", "algorithm"], as_index=False)
    .agg(
        avg_gap_pct=("gap_pct", "mean"),
        std_gap_pct=("gap_pct", "std"),
        total_time_s=("time_s", "sum"),
    )
    .sort_values(["avg_gap_pct", "total_time_s"], ignore_index=True)
)

vnd_summary = (
    df_vnd.groupby(["algorithm"], as_index=False)
    .agg(
        avg_gap_pct=("gap_pct", "mean"),
        std_gap_pct=("gap_pct", "std"),
        total_time_s=("time_s", "sum"),
    )
    .sort_values("avg_gap_pct", ignore_index=True)
)

it_summary.to_csv(PATH_TO_OUT / "it_im_summary_stats.csv", index=False)
vnd_summary.to_csv(PATH_TO_OUT / "vnd_summary_stats.csv", index=False)

display(it_summary)
display(vnd_summary)
# Out:
#    sol_start  pivot neighborhood                    algorithm  avg_gap_pct  \
# 0    c_and_w  first     exchange   c_and_w | first | exchange     2.648068
# 1     random  first     exchange    random | first | exchange     2.815505
# 2    c_and_w   best       insert      c_and_w | best | insert     3.103416
# 3     random   best       insert       random | best | insert     3.510550
# 4    c_and_w   best     exchange    c_and_w | best | exchange     3.601935
# 5     random   best     exchange     random | best | exchange     3.617111
# 6    c_and_w  first       insert     c_and_w | first | insert     3.977008
# 7     random  first       insert      random | first | insert     4.071038
# 8    c_and_w   best    transpose   c_and_w | best | transpose    21.606924
# 9    c_and_w  first    transpose  c_and_w | first | transpose    21.697428
# 10    random   best    transpose    random | best | transpose    34.126791
# 11    random  first    transpose   random | first | transpose    34.239876
#
#     std_gap_pct  total_time_s
# 0      0.427929    949.676310
# 1      0.480813   1082.478250
# 2      0.456996    298.969488
# 3      0.485157    324.001747
# 4      0.586407    164.760341
# 5      0.513357    173.165843
# 6      0.588091    343.755316
# 7      0.595324    331.066348
# 8      2.347384      0.040652
# 9      2.332077      0.015431
# 10     3.640453      0.040784
# 11     3.657756      0.015709
#                          algorithm  avg_gap_pct  std_gap_pct  total_time_s
# 0  transpose -> exchange -> insert     2.297919     0.457472    972.556230
# 1  transpose -> insert -> exchange     3.485551     0.606711    437.409519

# %%
def run_pairwise_tests(gap_matrix: pd.DataFrame) -> pd.DataFrame:
    rows = []
    for left, right in itertools.combinations(gap_matrix.columns, 2):
        paired = gap_matrix[[left, right]].dropna()
        if paired.empty:
            continue

        left_values = paired[left].to_numpy()
        right_values = paired[right].to_numpy()

        t_stat, t_p_value = ttest_rel(left_values, right_values, alternative="two-sided")

        diff = left_values - right_values
        if np.allclose(diff, 0.0):
            w_stat, w_p_value = 0.0, 1.0
        else:
            w_stat, w_p_value = wilcoxon(
                left_values,
                right_values,
                alternative="two-sided",
                zero_method="wilcox",
            )

        rows.append(
            {
                "algorithm_a": left,
                "algorithm_b": right,
                "n_instances": len(paired),
                "mean_gap_a": left_values.mean(),
                "mean_gap_b": right_values.mean(),
                "ttest_p_value": t_p_value,
                "wilcoxon_p_value": w_p_value,
                "significant_5pct_wilcoxon": w_p_value < 0.05,
            }
        )

    return pd.DataFrame(rows).sort_values("wilcoxon_p_value", ignore_index=True)


it_gap_matrix = df_it_imp.pivot(index="instance", columns="algorithm", values="gap_pct")
it_pairwise_tests = run_pairwise_tests(it_gap_matrix)
it_pairwise_tests.to_csv(PATH_TO_OUT / "it_im_pairwise_tests.csv", index=False)

vnd_gap_matrix = df_vnd.pivot(index="instance", columns="algorithm", values="gap_pct")
if vnd_gap_matrix.shape[1] != 2:
    raise ValueError(f"Expected exactly 2 VND algorithms, got {vnd_gap_matrix.shape[1]}")

vnd_a, vnd_b = vnd_gap_matrix.columns
vnd_paired = vnd_gap_matrix[[vnd_a, vnd_b]].dropna()

vnd_t_stat, vnd_t_p_value = ttest_rel(vnd_paired[vnd_a], vnd_paired[vnd_b], alternative="two-sided")
vnd_diff = vnd_paired[vnd_a].to_numpy() - vnd_paired[vnd_b].to_numpy()
if np.allclose(vnd_diff, 0.0):
    vnd_w_stat, vnd_w_p_value = 0.0, 1.0
else:
    vnd_w_stat, vnd_w_p_value = wilcoxon(
        vnd_paired[vnd_a],
        vnd_paired[vnd_b],
        alternative="two-sided",
        zero_method="wilcox",
    )

vnd_test = pd.DataFrame(
    [
        {
            "algorithm_a": vnd_a,
            "algorithm_b": vnd_b,
            "n_instances": len(vnd_paired),
            "mean_gap_a": vnd_paired[vnd_a].mean(),
            "mean_gap_b": vnd_paired[vnd_b].mean(),
            "ttest_p_value": vnd_t_p_value,
            "wilcoxon_p_value": vnd_w_p_value,
            "significant_5pct_wilcoxon": vnd_w_p_value < 0.05,
        }
    ]
)

vnd_test.to_csv(PATH_TO_OUT / "vnd_stat_test.csv", index=False)

display(it_pairwise_tests.head(20))
display(vnd_test)
# Out:
#                     algorithm_a                  algorithm_b  n_instances  \
# 0     c_and_w | best | exchange   c_and_w | best | transpose           78
# 1     c_and_w | best | exchange  c_and_w | first | transpose           78
# 2     c_and_w | best | exchange    random | best | transpose           78
# 3       c_and_w | best | insert   c_and_w | best | transpose           78
# 4     c_and_w | best | exchange   random | first | transpose           78
# 5       c_and_w | best | insert  c_and_w | first | transpose           78
# 6    c_and_w | best | transpose   random | first | transpose           78
# 7    c_and_w | best | transpose      random | first | insert           78
# 8    c_and_w | best | transpose     random | best | exchange           78
# 9    c_and_w | best | transpose       random | best | insert           78
# 10   c_and_w | best | transpose    random | best | transpose           78
# 11   c_and_w | best | transpose    random | first | exchange           78
# 12      c_and_w | best | insert   random | first | transpose           78
# 13   c_and_w | best | transpose   c_and_w | first | exchange           78
# 14   c_and_w | best | transpose     c_and_w | first | insert           78
# 15      c_and_w | best | insert    random | best | transpose           78
# 16   c_and_w | first | exchange     c_and_w | first | insert           78
# 17   c_and_w | first | exchange  c_and_w | first | transpose           78
# 18  c_and_w | first | transpose   random | first | transpose           78
# 19     random | best | exchange    random | best | transpose           78
#
#     mean_gap_a  mean_gap_b  ttest_p_value  wilcoxon_p_value  \
# 0     3.601935   21.606924   2.740434e-72      1.682175e-14
# 1     3.601935   21.697428   1.416243e-72      1.682175e-14
# 2     3.601935   34.126791   2.822794e-72      1.682175e-14
# 3     3.103416   21.606924   7.946926e-74      1.682175e-14
# 4     3.601935   34.239876   1.918494e-72      1.682175e-14
# 5     3.103416   21.697428   4.580310e-74      1.682175e-14
# 6    21.606924   34.239876   5.478845e-42      1.682175e-14
# 7    21.606924    4.071038   1.618288e-72      1.682175e-14
# 8    21.606924    3.617111   4.025905e-72      1.682175e-14
# 9    21.606924    3.510550   3.684326e-71      1.682175e-14
# 10   21.606924   34.126791   5.667523e-42      1.682175e-14
# 11   21.606924    2.815505   1.861325e-73      1.682175e-14
# 12    3.103416   34.239876   7.750631e-73      1.682175e-14
# 13   21.606924    2.648068   1.302876e-73      1.682175e-14
# 14   21.606924    3.977008   4.290780e-72      1.682175e-14
# 15    3.103416   34.126791   7.547135e-73      1.682175e-14
# 16    2.648068    3.977008   3.645405e-30      1.682175e-14
# 17    2.648068   21.697428   6.073629e-74      1.682175e-14
# 18   21.697428   34.239876   5.723677e-42      1.682175e-14
# 19    3.617111   34.126791   5.318284e-72      1.682175e-14
#
#     significant_5pct_wilcoxon
# 0                        True
# 1                        True
# 2                        True
# 3                        True
# 4                        True
# 5                        True
# 6                        True
# 7                        True
# 8                        True
# 9                        True
# 10                       True
# 11                       True
# 12                       True
# 13                       True
# 14                       True
# 15                       True
# 16                       True
# 17                       True
# 18                       True
# 19                       True
#                        algorithm_a                      algorithm_b  \
# 0  transpose -> exchange -> insert  transpose -> insert -> exchange
#
#    n_instances  mean_gap_a  mean_gap_b  ttest_p_value  wilcoxon_p_value  \
# 0           78    2.297919    3.485551   1.217030e-24      3.371464e-14
#
#    significant_5pct_wilcoxon
# 0                       True

# %%
plt.style.use("ggplot")  # emulate R style
PATH_TO_FIGS.mkdir(parents=True, exist_ok=True)

it_plot = it_summary.sort_values("avg_gap_pct")
it_order = it_plot["algorithm"].tolist()

fig_it_summary, axes = plt.subplots(figsize=(18, 6), constrained_layout=True)


axes.bar(it_plot["algorithm"], it_plot["total_time_s"], color="#457b9d")
axes.set_title("Iterative improvement: average time")
axes.set_ylabel("Total time across all instances (s)")
axes.set_xlabel("Algorithm")
axes.tick_params(axis="x", rotation=65)

fig_it_summary.savefig(PATH_TO_FIGS / "it_imp_summary.svg", format="svg")
plt.show()

fig_it_box, ax = plt.subplots(figsize=(16, 6), constrained_layout=True)
ax.boxplot(
    [df_it_imp.loc[df_it_imp["algorithm"] == algo, "gap_pct"] for algo in it_order],
    tick_labels=it_order,
    showmeans=True,
)
ax.set_title("Iterative improvement: instance-wise deviation distribution")
ax.set_ylabel("Deviation from best-known (%)")
ax.set_xlabel("Algorithm")
ax.tick_params(axis="x", rotation=65)
fig_it_box.savefig(PATH_TO_FIGS / "it_imp_boxplot.svg", format="svg")
plt.show()

vnd_order = vnd_summary["algorithm"].tolist()
fig_vnd, axes = plt.subplots(1, 2, figsize=(14, 5), constrained_layout=True)

axes[0].bar(vnd_summary["algorithm"], vnd_summary["avg_gap_pct"], color=["#f4a261", "#e76f51"])
axes[0].set_title("VND: average deviation")
axes[0].set_ylabel("Average deviation from best-known (%)")
axes[0].set_xlabel("Neighborhood order")
axes[0].tick_params(axis="x", rotation=20)

axes[1].boxplot(
    [df_vnd.loc[df_vnd["algorithm"] == algo, "gap_pct"] for algo in vnd_order],
    tick_labels=vnd_order,
    showmeans=True,
)
axes[1].set_title("VND: instance-wise deviation distribution")
axes[1].set_ylabel("Deviation from best-known (%)")
axes[1].set_xlabel("Neighborhood order")
axes[1].tick_params(axis="x", rotation=20)

fig_vnd.savefig(PATH_TO_FIGS / "vnd_summary.svg", format="svg")
plt.show()
